# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data2017 = pd.read_csv("/content/drive/My Drive/Movie/desc2017.csv")

# %%
data2018 = pd.read_csv("/content/drive/My Drive/Movie/desc2018.csv")
data2019 = pd.read_csv("/content/drive/My Drive/Movie/desc2019.csv")
data2020 = pd.read_csv("/content/drive/My Drive/Movie/desc2020.csv")
data2021 = pd.read_csv("/content/drive/My Drive/Movie/desc2021.csv")
data2022 = pd.read_csv("/content/drive/My Drive/Movie/desc2022.csv")

# %%
movies = data2018.append(data2019,ignore_index=True)

# %%
movies
# Out:
#          id                                           overview  \
# 0    406563  Parapsychologist Elise Rainier and her team tr...
# 1    426258  Mysterious events surround the travels of two ...
# 2    348389  A British Special Boat Service commando tracks...
# 3    468210  In 1929 in the outback of the Northern Territo...
# 4    399035  A businessman, on his daily commute home, gets...
# ..      ...                                                ...
# 514  431693  Super spy Lance Sterling and scientist Walter ...
# 515  331482  Four sisters come of age in America in the aft...
# 516  530915  At the height of the First World War, two youn...
# 517  522212  The powerful true story of Harvard-educated la...
# 518  565307  Years of carrying out death row executions hav...
#
#                                        tagline                    title  \
# 0                             Fear comes home.  Insidious: The Last Key
# ...

# %%
movies = movies.append(data2020,ignore_index=True)

# %%
movies = movies.append(data2021,ignore_index=True)

# %%
movies = movies.append(data2022,ignore_index=True)

# %%
movies
# Out:
#           id                                           overview  \
# 0     406563  Parapsychologist Elise Rainier and her team tr...
# 1     426258  Mysterious events surround the travels of two ...
# 2     348389  A British Special Boat Service commando tracks...
# 3     468210  In 1929 in the outback of the Northern Territo...
# 4     399035  A businessman, on his daily commute home, gets...
# ...      ...                                                ...
# 1480  850028  A young woman trapped in an abusive relationsh...
# 1481  647808  Catherine Tate's iconic character Nan hits the...
# 1482  647808  Catherine Tate's iconic character Nan hits the...
# 1483  647808  Catherine Tate's iconic character Nan hits the...
# 1484  647808  Catherine Tate's iconic character Nan hits the...
#
#                                                tagline  \
# 0                                     Fear comes home.
# 1                                                  NaN
# ...

# %%
descfinal_data = data2017.append(movies,ignore_index=True)

# %%
descfinal_data
# Out:
#            id                                           overview  \
# 0         862  Led by Woody, Andy's toys live happily in his ...
# 1        8844  When siblings Judy and Peter discover an encha...
# 2       15602  A family wedding reignites the ancient feud be...
# 3       31357  Cheated on, mistreated and stepped on, the wom...
# 4       11862  Just when George Banks has recovered from his ...
# ...       ...                                                ...
# 10579  850028  A young woman trapped in an abusive relationsh...
# 10580  647808  Catherine Tate's iconic character Nan hits the...
# 10581  647808  Catherine Tate's iconic character Nan hits the...
# 10582  647808  Catherine Tate's iconic character Nan hits the...
# 10583  647808  Catherine Tate's iconic character Nan hits the...
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# ...

# %%
descfinal_data[descfinal_data['title'].isnull()]
# Out:
#            id                                           overview  \
# 10251  647808  Catherine Tate's iconic character Nan hits the...
# 10580  647808  Catherine Tate's iconic character Nan hits the...
# 10581  647808  Catherine Tate's iconic character Nan hits the...
# 10582  647808  Catherine Tate's iconic character Nan hits the...
# 10583  647808  Catherine Tate's iconic character Nan hits the...
#
#                       tagline title  \
# 10251  A coming of age movie.   NaN
# 10580  A coming of age movie.   NaN
# 10581  A coming of age movie.   NaN
# 10582  A coming of age movie.   NaN
# 10583  A coming of age movie.   NaN
#
#                                                     comb
# 10251  Catherine Tate's iconic character Nan hits the...
# 10580  Catherine Tate's iconic character Nan hits the...
# 10581  Catherine Tate's iconic character Nan hits the...
# 10582  Catherine Tate's iconic character Nan hits the...
# 10583  Catherine Tate's iconic character Nan hits the...

# %%
descfinal_data['title'] = descfinal_data['title'].str.lower()

# %%
descfinal_data.drop([10251,10580,10581,10582,10583])
# Out:
#            id                                           overview  \
# 0         862  Led by Woody, Andy's toys live happily in his ...
# 1        8844  When siblings Judy and Peter discover an encha...
# 2       15602  A family wedding reignites the ancient feud be...
# 3       31357  Cheated on, mistreated and stepped on, the wom...
# 4       11862  Just when George Banks has recovered from his ...
# ...       ...                                                ...
# 10575  696157  The joyous, emotional, heartbreaking celebrati...
# 10576  800815  A seasoned detective investigates a series of ...
# 10577  777245  A group of women in an isolated Mennonite comm...
# 10578  937278  The story of Otto Anderson, a grumpy widower w...
# 10579  850028  A young woman trapped in an abusive relationsh...
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# ...

# %%
descfinal_data.to_csv('descfinal_data.csv',index=False)

# %%
from google.colab import files
files.download("descfinal_data.csv")
